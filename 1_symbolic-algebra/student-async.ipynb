# %% [markdown]
# # Lesson 1: Introduction to Symbolic Algebra in Python
# ---

# %% [markdown]
# The purpose of this lesson is to help students develop foundational skills for performing symbolic algebra in Python using the SymPy library and its `algebra_with_sympy` wrapper, with some brief applications to problem solving at the general chemistry (first-year) level.

# %% [markdown]
# ### Resources

# %% [markdown]
# #### Cyberinfrastructure Resources

# %% [markdown]
# - {u}`[MolSSI Workshop: Python Scripting for Computational Molecular Sciences](https://education.molssi.org/python_scripting_cms/)`
# - {u}`[MolSSI CMS Python Workshop: Introduction](https://education.molssi.org/python_scripting_cms/01-introduction/index.html)`
# - {u}`[Algebra with SymPy Documentation](https://gutow.github.io/Algebra_with_Sympy/algebra_with_sympy.html)`
# - {u}`[Demonstrations of ``algebra_with_sympy`` functionality with the ``Equation`` class](https://gutow.github.io/Algebra_with_Sympy/Demonstration%20of%20equation%20class.html)`

# %% [markdown]
# #### Content Resources

# %% [markdown]
# * {u}`[OpenStax Chemistry 2e](https://openstax.org/details/books/chemistry-2e)`
# * {u}`[OpenStax Atoms-First Chemistry 2e](https://openstax.org/details/books/chemistry-atoms-first-2e)`

# %% [markdown]
# ### References

# %% [markdown]
# ## Notebook Setup

# %% [markdown]
# ### Package Imports

# %% [markdown]
# :::{warning} ⚒ Importing necessary packages
# :icon: false
#
# Execute the cell below to ensure all necessary Python libraries are loaded.
# :::

# %%
# EXECUTE: Import some packages that we will use later
## SymPy imports & setting defaults
from algebra_with_sympy import * # Automatically imports sympy
algwsym_config.output.solve_to_list = True # Makes automatic solution outputs a list for usability
from sympy.plotting import plot as symplot
from sympy.plotting import plot3d as symplot3d
from IPython.display import display, Markdown
from sympy.functions.elementary.exponential import log as sylog
from sympy.codegen.cfunctions import log10 as sylog10
## Numerical libraries: Math, NumPy, & SciPy
import math
from math import log as mlog
from math import log10 as mlog10
import numpy as np
import scipy as sp
from scipy.integrate import quad as spquad
from scipy.integrate import dblquad as spdblquad
from scipy.integrate import tplquad as sptplquad
from scipy.integrate import nquad as spnquad
## Sanity check
print(f"This notebook is running Algebra_with_Sympy version {str(algwsym_version)}.")

# %% [markdown]
# # I. Declaring Mathematical Variables & Expressions

# %% [markdown]
# Python variables are named containers to which some data has been assigned, and this assignment must occur before a variable can be used or called. While mathematical variables (e.g., $x$, $T$, etc.) are used to represent _unknown_ quantities in algebraic expressions (i.e., without a value yet assigned), a symbol must similarly be _declared_ as a mathematical variable in SymPy before it can be used.

# %% [markdown]
# ## I.A. SymPy Variable Declaration

# %% [markdown]
# ::::{tip}🐍 Declaring a Scalar Variable in SymPy
# :icon:false
# To declare a symbol representing an unknown scalar quantity (i.e., a number without an associated direction) as a SymPy variable, use the `var()` function:
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration: Declaring variables with var()
# # Declare variable x by passing string containing symbol
# var('x')
# # Can declare multiple variables at a time, separate by spaces
# var('y z')
# # Can use Greek letters if you like, just spell the letter
# var('alpha beta')
# # Can even use subscripts and superscripts
# var('q T_1 T_2 C^solid')
# ```
#
# :::{danger}⚠️ Author Note on Terminology: Python vs. SymPy "Variables"
# :icon:false
# Unfortunately, the word "variable" is used in both coding and mathematical contexts. To avoid confusion, I will explicitly refer to the mathematical symbols used in SymPy expressions as "math variables" or "SymPy variables" and named Python variables as "Python variables" to distinguish the two contexts.
# :::
# ::::

# %% [markdown]
# Once some SymPy variables have been declared, it is possible to use them to define an algebraic expression in SymPy.

# %% [markdown]
# ## I.B. Defining SymPy Expressions

# %% [markdown]
# ~~~{warning}⚒️ Your Turn
# :icon:false
# In the cell below,
# 1. Declare the SymPy varialbe $x$
# 2. Use the newly declared SymPy variable $x$ to define the expression for the linear function
#     \begin{equation*}
#     f(x) = 5x+2
#     \end{equation*}
#     by encoding the right-hand-side of the equation above and assigning it to the Python varialbe `f` using the Python assignment operator `=`.
# 4. On the final line of the cell, type the Python variable for your function to "pretty-print" the function using a cell return.
#
# ::::{tip}💡 Hints
# :icon:false
# :class:dropdown
# :::{note} Mutliplication must be explicit
# :icon:false
# :class:dropdown
# While multiplication is often implied in mathematical expressions when two symbols are adjacent (i.e., $3x = 3\cdot x$), there is no such understanding in Python or SymPy. All mutliplication must be shown explicitly, so $3x \Rightarrow$ `3*x`!
# :::
# ::::
# ~~~

# %%
# YOUR TURN: Encoding a SymPy Expression

# %% [markdown]
# ::::{warning}✅ Check Yourself
# :icon:false
# :class:dropdown
# Your code solving the example above should resemble the following:
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN: Encoding a SymPy Expression
# ## Declare variable
# var('x')
#
# ## Define function f(x) = 5x+2
# f = 5*x + 2
#
# ## Pretty-print with a cell return
# f
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle 5x+2$
# :::
# ::::

# %% [markdown]
# ## I.C. Variable Domain

# %% [markdown]
# While mathematical variables that we declare in SymPy to represent unknown quantities don't yet have a particular numerical value, we may know in in general what kinds of values a variable can assume, called the the _mathematical domain_ (a.k.a. _domain_ for short) of our variables.
#
# When using SymPy to solve chemical problems, it is extremely likely that varibles must be positive --- after all, it's not possible to measure a negative mass! --- so to maximize SymPy's utility, we should therefore get in the habit of defining the _mathematical domain_ (a.k.a. _domain_ for short) of our SymPy variables at declaration time!

# %% [markdown]
# ::::{tip}🐍 Specifying the Domain of a SymPy Variable
# :icon:false
# When a SymPy variable represents a chemically or physically observable quantity, it is important to define the _variable domain_ to ensure SymPy behaves in a physically reasonable manner. To specify the domain of a SymPy variable, set one or more _assumptions_ to be `True` by passing them as keyword arguments to the `var()` function:
#
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration
# # Variables representing arbitrary real numbers
# var('x y z', real=True)
# # Positive, nonzero real number representing mass
# var('m', real=True, positive=True, nonzero=True)
# # Nonnegative integer representing principle quantum number
# var('n', integer=True, nonnegative=True)
# ```
#
# :::{warning} ⚠️ Caution: Separate declaration of variables with different domains or assumptions
# :icon:false
# :class:dropdown
# The keyword arguments passed to `var()` to specify domain and any other assumptions apply to _every_ variable declared with that call to `var()`, so if different variables have different domains/assumptions, they must be declared separately!
#
# For example, in thermochemical contexts the heat $q$ can be negative, zero, or positive, but the absolute temperature $T$ can only be positive:
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration
# # Declare variables
# var('q', real=True) # Heat can be any real number
# var('m C T_1 T_2', real=True, positive=True, nonzero=True) # mass, heat capacity, and temperature must strictly positive
# ```
# :::
#
# Below are listed several variable domains which may be appropriate depending on the chemical context or application of interest, as well as several other useful assumptions that can be used to restrict which values in the larger domain are allowed.
#
# :::{note}ℹ️ Common Variable Domains
# :icon:false
# :class:dropdown
# Definitions for some potentially relevant variable domains, as well as how they may be specified as a keyword argument to the `var()` function.
#
# Real Numbers
# : A _real number_ $c$ is any numerical value $-\infty < c < \infty$ that can be measured; the set of all real numbers is denoted $\mathbb{R}$.
#     * {u}`Examples:` $5$, $\pi$, $5.32$, $\tfrac{1}{2}$
#     * {u}`Syntax:` `real=True`
#
# Imaginary Numbers
# : _**The** imaginary number_ is $i = \sqrt{-1}$.
# : A number $z$ is said to be _imaginary_ (a.k.a. _pure imaginary_) if it is a multiple of the imaginary number $i$, i.e., $z = \pm bi$ for some real number $b$.
#     * {u}`Syntax:` `imaginary=True`
#
# Complex Numbers
# : A _complex number_ $z = a \pm bi$ (for real constants $a,b$) is one which contains _both_ a real and imaginary part; the set of all complex numbers is denoted $\mathbb{C}$.
#     * {u}`Syntax:` `complex=True`
#
# Integers
# : An _integer_ is a real counting number, i.e., $0, +1, -1, +2, -2,\ldots$; the set of all integers is denoted $\mathbb{Z}$.
#     * {u}`Syntax:` `integer=True`
# :::
# :::{note}ℹ️ Additional Useful Assumptions
# :icon:false
# :class:dropdown
# For the purposes of illustration, let $x$ represent a real number. The following assumptions can be passed as keyword arguments to `var()` to add additional limitations on which values within $\mathbb{R}$ (or any other domain) the variable $x$ is allowed to assume.
#
# Positive
# : $x > 0$
#
# Negative
# : $x < 0$
#
# Nonnegative
# : $x\geq 0$
#
# Nonpositive
# : $x\leq 0$
#
# Nonzero
# : $x\neq 0$
# :::
#
# For a complete list of variable domains and possible assumptions, along with precise mathematical definitions for each, refer to {u}`[the Predicates section of the SymPy documentation.](https://docs.sympy.org/latest/guides/assumptions.html#predicates)`
# ::::

# %% [markdown]
# :::{danger}☢️ Danger: Variables with Unspecified Domain May Behave Unphysically
# :icon:false
# SymPy is a general purpose mathematics library, and by default assumes that all variables are complex (i.e., a member of $\mathbb{C}$ with both a real and imaginary part). This can lead to potentially unphysical behavior when solving equations or performing calculus operations like integration, which will produce erroneous results even if no explicit syntax error is thrown.
#
# To avoid unphysical behavior, ***explicitly specify the domain of all SymPy variables when they are declared!***
# :::

# %% [markdown]
# :::{warning} ⚒️ Your Turn
# :icon:false
# In chemical kinetics, the rate constant for an elementary reaction (i.e., one without any intermediates) can be computed using the Arrhenius equation
# \begin{equation}
# k = A e^{-E_a / RT}
# \label{eqn:arrhenius-k}
# \end{equation}
# where the _frequency factor_ $A$ is a positive real number representing the likelihood of particle collisions, the _activation energy_ $E_a$ is a nonnegative real number representing the energetic penalty necessary for the reaction to proceed, $R = 8.314 {\rm\ J\cdot mol^{-1}\cdot K^{-1}}$ is the ideal gas constant, and $T$ is the aboslute temperature.
#
# In the cell below,
# 1. Declare SymPy variables with appropriate domain and additional assumptions specified for each,
# 2. sing the SymPy variables you just declared, encode the right-hand-side of the Arrhenius equation above and assign the resulting SymPy expression to the Python variable `arrhenius_k`
# 3. Pretty-print your expression assigned to `arrhenius_k` using a cell return, and verify it agrees with [Eqn. %s](#eqn:arrhenius-k) above.
#
# :::{tip}💡 Hints
# :icon:false
# :class:dropdown
# 1. Recall that in SymPy, the exponential function $e^u$ is available using the `exp()` function.
# :::

# %%
# YOUR TURN: Define expression for the Arrhenius rate constant

# %% [markdown]
# # II. Evaluating a SymPy Expression

# %% [markdown]
# After encoding a mathematical expression in terms of SymPy variables, how can we substitute particular values for these variables to evaluate the expression?

# %% [markdown]
# ## II.A. Substituting Values into an Expression

# %% [markdown]
# ::::{tip}🐍 Substituting Values into a SymPy Expression
# :icon:false
# To evaluate a SymPy expression for particular values of its variables, use the `.subs()` method, whose argument is a Python dictionary mapping each SymPy variable to a particular value.
#
# :::{note}👀 Python Dictionaries
# :icon: false
# :class:dropdown
# Python dictionaries are objects of type `dict` which associate values with the keys that are used to "look them up," and are defined by placing comma-separated `key: value` pairs inside curly braces like the following:
# ```{code}python
# new_dict = {'key_1': 'value 1', 'key_2': 'value 2', 'key_3': 3, 'key_4': ideal_T}
# ```
# In general, a dictionary's keys should be defined as strings (type `str`), and behave like Python variables that only live inside the dictionary. The dictionary's values, on the other hand, can be any mixture of types (i.e., not all entries in the dictionary must be of the same type). To access the value associated with a particular key in the dictionary, you would use square brackets `[]`:
#
# ```{code}python
# :linenos:
# :filename: Cell Input
# print(new_dict[key_1])
# ```
# ```{code}txt
# :filename: Cell Output
# value_1
# ```
# This is similar to accessing a member of a `list`, except instead of passing the integer index of the list element, you pass the `str` name of the desired value's key inside the brackets.
# :::
#
# For example, the following syntax will evaluate the function $f(x) = -ax^2$ where $-\infty < x < \infty$ and $a>0$ for the particular values $a=\tfrac{1}{2}$ and $x=1.234$:
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration: Evaluating a SymPy Expression with subs()
# # Declare variables, define function f(x)
# var('x', real=True)
# var('a', real=True, positive=True, nonzero=True)
# f = exp(-a * x**2)
#
# # Substitute values with subs(), directly pretty-print output
# f.subs({x:1.234, a:1/2})
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle 0.467022426491753$
# :::
#
# ::::

# %% [markdown]
# :::{warning}⚒️ Your Turn
# :icon:false
# Using the `.subs()` method and the SymPy expression `arrhenius_k` you defined above, determine the value of the elementary rate constant $k$ according to [Eqn. %s](#eqn:arrhenius-k) at $T=310 K$ if the frequency factor is $A = 12.213 {\rm\ M^{-1}s^{-1}}$ and the activation energy is $E_a = 40.82 {\rm\ kJ\cdot mol^{-1}}$.
# :::{tip}💡 Hints
# :icon:false
# :class:dropdown
# Make sure you convert your energy units so that $E_a$ and $R$ agree!
# :::

# %%
# Your Turn: Substituting into a SymPy Expression

# %% [markdown]
# ~~~{warning} ✅ Check Yourself
# :icon:false
# :class:dropdown
# You should have determined that the elementary rate constant is $k\approx 1.62\times 10^{-6} {\rm\ M^{-1}\cdot s^{-1}}$.
#
# ::::{tip}🐍 Code Key
# :icon:false
# :class:dropdown
# Your code solving the example above could resemble the following:
# ```{code}python
# :linenos:
# :filename:Python Input
# # Your Turn: Substituting into a SymPy Expression
# ## Values for constants to substitute into existing arrhenius_k expression
# A_val = 12.213 # 1/(M*s)
# Ea_val = 40.82 * 1000 # kJ/mol -> J/mol
# R_val = 8.314 # J/(mol*K)
# T_val = 310 # K
#
# # Substitute values with subs(), directly pretty-print output
# arrhenius_k.subs({A:A_val, E_a:Ea_val, R:R_val, T:T_val})
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle 1.61603715758069\cdot 10^{-6}$
# :::
# ::::
# ~~~

# %% [markdown]
# ## II.B. Float-Evaluation

# %% [markdown]
# Since SymPy is designed for _symbolic_ mathematics, SymPy will by default attempt to symbolically represent the result of evaluating an expression whenever possible. To demonstrate this behavior, consider the example below:

# %% [markdown]
# :::{warning} ⚒️ Your Turn
# :icon:false
# In the cell below,
# 1. Encode the function $g(t) = \sqrt{t}$ of the real nonnegative variable $t\geq 0$, and assign to the Python variable `g`
# 2. Evaluate $g(t)$ for the following particular values of $t$
#     | Part | Input Value, ${\bm t}$          |
#     |:----:|:-------------------------------:|
#     | (a)  | $\displaystyle t = \frac{1}{2}$ |
#     | (b)  | $\displaystyle t = 2$           |
#     | (c)  | $\displaystyle t = \pi$         |
#     | (d)  | $\displaystyle t = 4.21$        |
# :::{tip}💡 Hints
# :icon:false
# :class:dropdown
# For the purposes of this demonstration,
# 1. Use the SymPy function `sqrt()` for the square root rather than raising a variable to the half power
# 2. For part (a), substitute in the fraction `1/2` rather than the decimal value `0.5`
# ::::::

# %%
# YOUR TURN: Demonstrating default symbolic evaluation

# %% [markdown]
# :::{warning} ✅ Check Yourself
# :icon:false
# :class:dropdown
# You should have evaluated the function $g(t) = \sqrt{t}$ to yield the following outputs from SymPy, formatted exactly as follows:
# | Part | Input Value, ${\bm t}$          | Function Output, ${\bm g}({\bm t})$ |
# |:----:|:-------------------------------:|:------------------------------------|
# | (a)  | $\displaystyle t = \frac{1}{2}$ | $\displaystyle g\left(\tfrac{1}{2}\right) = \frac{\sqrt{2}}{2}$ |
# | (b)  | $\displaystyle t = 2$           | $\displaystyle g(2) = \sqrt{2}$ |
# | (c)  | $\displaystyle t = \pi$         | $\displaystyle g(\pi) = \sqrt{\pi}$ |
# | (d)  | $\displaystyle t = 4.21$        | $\displaystyle g(4.21) = 2.05182845286832$ |
# :::

# %% [markdown]
# As you should have seen from the demonstration above, if there is an _exact_ representation of the result of evaluating an expression with `.subs()` (i.e., in terms of potentially infinite decimals like $\pi$, $e$, $\sqrt{2}$, etc.), SymPy will leave the result in symbolic form rather than returning an _approximate_ decimal representation.
#
# While this behavior certainly useful, the errors in the measured quantities being substituted into expressions for common scientific applications are enormous relative to the miniscule roundoff errors involved with terminating these irrational numbers. So, how can we directly convert these exact answers into decimal form?

# %% [markdown]
# ::::{tip} 🐍 Float-Evaluating a SymPy Expression
# :icon:false
# To return a floating-point (decimal) representation of the output from evaluating a SymPy expression with the `.subs()` method, call the `.evalf()` method on the result:
# ```{code}python
# :linenos:
# :filename:Python Input
# # Syntax Demonstration: Float-Evaluating a SymPy Expression
# ## Declare variable, define g(t)
# var('t', real=True)
# g = sqrt(t)
#
# ## Substitute & float-evaluate g(t) w/ .evalf() method
# g.subs({t:pi}).evalf()
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle 1.772453850905516$
# :::
# ::::

# %% [markdown]
# :::{warning}⚒️ Your Turn
# :icon:false
# Re-solve parts (a)-(c) from the previous example, however call the `.evalf()` method on the returned symbolic expression to float-evaluate the function instead.
# :::

# %%
# YOUR TURN: Demonstrating default symbolic evaluation

# %% [markdown]
# :::{warning} ✅ Check Yourself
# :icon:false
# :class:dropdown
# Float-evaluating the function $g(t)$ for parts (a)-(c) of the previous example should have produced the following decimal results:
# | Part | Input Value, ${\bm t}$          | Function Output, ${\bm g}({\bm t})$ |
# |:----:|:-------------------------------:|:------------------------------------|
# | (a)  | $\displaystyle t = \frac{1}{2}$ | $\displaystyle g\left(\tfrac{1}{2}\right) = \frac{\sqrt{2}}{2} \approx 0.7071067811865476$ |
# | (b)  | $\displaystyle t = 2$           | $\displaystyle g(2) = \sqrt{2} \approx 1.4142135623730951$ |
# | (c)  | $\displaystyle t = \pi$         | $\displaystyle g(\pi) = \sqrt{\pi} \approx 1.772453850905516$ |
# :::

# %% [markdown]
# Once an expression has been float-evaluated it is often useful to save the result for later use, however even though it looks like a decimal, the output of the `.evalf()` method is a derived SymPy object rather than the native Python `float` type. To keep the _numerical data itself_ for future use, cast the output from `.evalf()` to be the native Python floating point type!

# %% [markdown]
# ::::{tip} 🐍 Typecasting the Result of a Float Evaluation
# :icon:false
# To keep the foating point decimal result from calling `.evalf()`, use typecasting to convert it into a Python `float` and assign to a Python variable:
# ```{code}python
# :linenos:
# :filename:Python Input
# # Syntax Demonstration: Float-Evaluating a SymPy Expression
# ## Declare variable, define g(t)
# var('t', real=True)
# g = sqrt(t)
#
# ## Float-evaluate g(t) w/ .evalf() method, typecast to Python float
# g_val = float(g.subs({t:pi}).evalf())
# print(g_val)
# print(type(g_val))
# ```
# ```{code}txt
# :filename:Cell Output
# 1.772453850905516
# <class 'float'>
# ```
# ::::

# %% [markdown]
# :::{warning} ⚒️ Your Turn
# :icon:false
# Consider the bimolecular elementary reaction
# \begin{equation*}
# {\rm A} + {\rm B} \rightarrow {\rm products}
# \end{equation*}
# whose rate law is $v = k[{\rm A}][{\rm B}]$.
#
# In the cell below,
# 1. Determine the value of the elementary rate constant $k$ according to [Eqn. %s](#eqn:arrhenius-k) at $T=310 K$ if the frequency factor is $A = 12.213 {\rm\ M^{-1}s^{-1}}$ and the activation energy is $E_a = 40.82 {\rm\ kJ\cdot mol^{-1}}$. Cast the resulting value to be of type `float` and assign it to the Python variable `k_val`.
# 2. Using the value of the rate constant assigned to `k_val` and the expression for the rate law for this elementary reaction, determine the rate $v$ if $[{\rm A}] = 0.250{\rm\ M}$ and $[{\rm B}] = 0.125{\rm\ M}$.
#
# :::{tip}💡 Hints
# :icon:false
# :class:dropdown
# To declare a SymPy variable representing concentration which is formatted like $[{\rm X}]$, use the following syntax:
# ```{code}python
# :linenos:
# CX = Symbol(r'[X]')
# ```
# which can then be used to within a SymPy expression as `CX`.
# ::::::

# %%
# YOUR TURN: Rate of a Bimolecular Elementary Reaction

# %% [markdown]
# :::{warning} ✅ Check Yourself
# :icon:false
# :class:dropdown
# You should have determined that the rate of the reaction under these conditions is $v \approx 5.05\times 10^{-8} {\rm\ M\cdot s^{-1}}$.
#
# :::{tip}🐍 Code Key
# :icon:false
# :class:dropdown
# Your code solving this example could resemble the following:
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN: Rate of a Bimolecular Elementary Reaction
# ## Part 1: Determine value of rate constant
# ### Declare variables, define Arrhenius eqn
# var('A R T', real=True, positive=True, nonzero=True)
# var('E_a', real=True, nonnegative=True)
# arrhenius_k = A*exp(-(E_a / (R*T)))
#
# ### Define values for constants
# A_val = 12.213 # 1/(M*s)
# Ea_val = 40.82 * 1000 # kJ/mol -> J/mol
# R_val = 8.314 # J/(mol*K)
# T_val = 310 # K
#
# ### Substitute, evalf, typecast to float, store value for rate constant
# k_val = float(arrhenius_k.subs({A:A_val, E_a:Ea_val, R:R_val, T:T_val}).evalf())
#
# ## Part 2: Rate of the Bimolecular Elementary Step
# ### Declare variables & define rate law
# var('k', real=True, positive=True, nonzero=True)
# CA = Symbol(r'[A]')
# CB = Symbol(r'[B]')
# v = k*CA*CB
#
# ### Store concentration values in Python variables
# CA_val = 0.250 # M
# CB_val = 0.125 # M
#
# ### Substitute into rate law
# v_val = float(v.subs({k:k_val, CA:CA_val, CB:CB_val}).evalf())
#
# ### Printing
# print(f"The rate of the reaction is v={v_val:6.2E} M/s for k={k_val:6.2E} 1/(M*s), [A]={CA_val} M, [B]={CB_val} M")
# ```
# ```{code}txt
# :filename:Cell Output
# The rate of the reaction is v=5.05E-08 M/s for k=1.62E-06 1/(M*s), [A]=0.25 M, [B]=0.125 M
# ```
# ::::::

# %% [markdown]
# # III. Mathematical Equalities

# %% [markdown]
# For a mathematical function
# \begin{equation*}
# f(x) = e^{-a/bx},
# \end{equation*}
# encoding the $f(x)$ by defining a SymPy expression for only the right-hand-side and assigning it to the Python variable `f` is a sensible strategy because we are mostly interested in evaluating the function for a particular value of the independent variable $x$.
#
# For many relationships in chemistry like the Arrhenius equation of [Eqn. %s](#eqn:arrhenius-k), however, the quantity on the left-hand-side of the equality also represents a physically measurable quantity --- and we may wish to rearrange [Eqn. %s](#eqn:arrhenius-k) to solve for any of the other quantities instead (e.g., activation energy $E_a$)!
#
# Rather than encoding only the expression on the right-hand-side of the equality, how can we encode the _entire equation_ in SymPy?

# %% [markdown]
# ## III.A. Defining Named Equalities

# %% [markdown]
# ::::{tip}🐍 Encoding a Mathematical Equality into SymPy
# :icon:false
# To encode a mathematical equality in SymPy and assign it to a Python variable so that it can be manipulated later, use the special assignment operator `=@`.
#
# For example, the equation defining a circle in the $xy$-plane centered at the origin with radius $r=1$ is
# \begin{equation*}
# x^2 + y^2 = 1
# \end{equation*}
# which can be encoded and assigned to the Python variable `unit_circle` with the syntax
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration: Defining & Assigning a Mathematical Equality into SymPy
# # Declare variables for unit circle
# var('x y', real=True)
# # Define ideal gas law
# unit_circle =@ x**2 + y**2 = 1
# # Pretty-print the ideal gas law equation from SymPy
# unit_circle
# ```
# :::{note} ⏎ Cell Output
# :icon:false
# $\displaystyle x^2 + y^2 = 1\;\;\; ({\tt unit\_circle})$
# :::
#
# :::{note}👀 Note: Mathematical $=$ vs. Python Assignment Operator `=`
# :icon:false
# :class:dropdown
# Equations involve two expressions which are mathematically equivalent, which is represented symbolically using the _mathematical equals sign_ "$=$", i.e.,
# \begin{equation*}
# {\rm left-hand\ side\ (lhs)} = {\rm right-hand\ side\ (rhs)}
# \end{equation*}
# Unfortunately, this symbol has a double-meaning in Python, as the _assignment oeprator_ `=` which uniquely associates a value with a named variable, i.e.,
# ```{code}python
# my_var = 5
# ```
# To distinguish these contexts, this and future lessons will specify either the _mathematical equals_ "$=$" vs. the _Python assignment operator_ `=`.
# :::
# :::{danger}⛔️ Error Avoidance: Do Not Include Special Assignment Operator `=@` in Code Comments
# :icon:false
# :class:dropdown
# The special assignment operator `=@` is not standard Python, but is instead a custom addition of the `algebra_with_sympy` wrapper library that we use to make SymPy easier to use. Because of how the `=@` operator is captured by `algebra_with_sympy`, this operator _can ONLY be present when syntactically meaningful._ ***Even having `=@` inside a code comment will throw a syntax error!!!***
# ::::::

# %% [markdown]
# :::{warning}⚒️ Your Turn
# :icon:false
# In the cell below,
# 1. Declare SymPy variables $P,\ V,\ n,\ R,\ \&\ T$ representing the state variables for an ideal gas, specifying the proper mathematical domain for each.
# 2. Define the ideal gas equation $PV = nRT$ involving a mathematical equals, and assign the equation to the Python variable `ideal_gas` using the special assignment operator `=@`
# 3. Pretty-print the contents of `ideal_gas` using a cell return to verify your equation is correct!
# :::

# %%
# YOUR TURN: Define Ideal Gas Law

# %% [markdown]
# ## III.B. Manual Algebraic Rearrangement

# %% [markdown]
# Because a mathematical equation defines the relationship between the variables which are present in the equation, it allows us to solve for any variable rather than merely evaluating to a single type of result. How can we use the SymPy to manually rearrange a mathematical equality?

# %% [markdown]
# ::::{tip}🐍 Manual Algebraic Rearrangement of a SymPy Equation
# :icon:false
# Consider the equation $x + 5 = 2$. To algebraically rearrange this equation to solve for $x$, we need to subtract 5 from both sides:
# \begin{align*}
# x + &5 &&= 2 \\
#   - &5 &&{}\;\;\;\; - 5\\
#     &x &&= 2 - 5 = -3
# \end{align*}
# In SymPy all arithmetic operations performed on a named equation will be applied to both sides of the equality, so the rearrangement above can be accomplished with
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration
# # Declare variables & define named equation
# var('x', real=True)
# eqn =@ x + 5 = 2
# # Rearrange by subtracting 5 from each side, assign to Python variable for posterity
# eqn_x = eqn - 5
# # Pretty-print w/ cell return
# eqn_x
# ```
# :::{note} ⏎ Cell Return
# :icon:false
# $\displaystyle x = -3$
# :::
# :::{warning}⚠️ Author Note: Assignment Statements Not Involving Math "$=$"
# :icon:false
# All Python assignment statements _which do not explicitly include the mathematical equals character_ $=$ in the SymPy equation must use the standard Python assignment operator `=` and **not the special assignment character** `=@`!
# :::
# ::::

# %% [markdown]
# :::{warning}⚒️ Your Turn
# :icon:false
# In the cell below,
# 1. Rearrange the ideal gas equation you defined earlier to solve for the pressure $P$, and assign this new equation to the Python variable `ideal_P`.
# 2. Use the rearranged equation `ideal_P` to evaluate the pressure (atm) exerted by 1.00 mol of an ideal gas at 273 K in a 24.0 L vessel.
# :::

# %%
# YOUR TURN: Pressure of an ideal gas

# %% [markdown]
# ::::{warning} ✅ Check Yourself
# :icon:false
# :class:dropdown
# You should have determined that for 1.00 mol of an ideal gas at 273 K in a 24.0 L vessel, $P \approx 0.933 {\rm\ atm}$.
#
# :::{tip}🐍 Code Key
# :icon:false
# :class:dropdown
# ```{code}python
# :linenos:
# :filename:Python Input
#  YOUR TURN: Pressure of an ideal gas
# ## Rearrange ideal gas law for P, assign to Python variable
# ideal_P = ideal_gas / V
# ## Evaluate pressure @ T=273 K, V = 24.0 L, n = 1.00 mol
# ideal_P.subs({n:1.00,   # mol
#               V:24.0,   # L
#               T:273,    # K
#               R:0.08206 # L*atm/mol/K
#              })
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle P = 0.9334325$
# :::
# ::::

# %% [markdown]
# ## III.C. Automatically Solving Equations

# %% [markdown]
# Manually rearranging an algebraic expression for a particular variable is useful when it is straightforward to do so, however plenty of chemical applications require solving e.g. quadratic equations or systems of equations whose manual solution is significantly more laborious. Fortunately, SymPy has the capability to _automatically_ solve for a particular variable in an equation using the `solve()` function.

# %% [markdown]
# ::::{tip}🐍 Automatically Solving SymPy Equations with the `solve()` Function
# :icon:false
# To solve a named SymPy equation for a particular variable, use the `solve()` function.
#
# For example, the ideal gas law $PV = nRT$ could have been solved for the pressure $P$ automatically using the syntax
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration for solve() Function
# # Pass named equation and variable for which to solve as arguments, returns a list
# solutions = solve(ideal_gas, P)
# solutions[0] # For equations with only one solution, access by indexing 0th element
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle P = \frac{nRT}{V}$
# :::
# :::{tip}🐍 Controlling the Output Type from SymPy `solve()`
# :icon:false
# :class:dropdown
# By default, the output from the `solve()` function is a built-in set type, however this behavior has been changed in this notebook thanks to the line
# ```{code}python
# :filename:Setting option to control output type from solve() function
# algwsym_config.output.solve_to_list = True # Makes automatic solution outputs a list for usability
# ```
# which is in the import cell in the {u}`[](#package-imports)` section above.
# :::
# ::::

# %% [markdown]
# :::{warning}⚒️ Your Turn
# :icon:false
# Consider a perfectly insulated vessel containing a $50.00 {\rm\ g}$ sample of water (specific heat capacity $C_{\rm H_2O} = 4.184 {\rm\ J\cdot g^{-1}\cdot{}^{\circ}C^{-1}}$) initially at $25.00 {\rm\ \cdot{}^{\circ}C^{-1}}$, into which $50.00 {\rm\ g}$ of lead pellets (specific heat capacity $C_{\rm Pb} = 0.130 {\rm\ J\cdot g^{-1}\cdot{}^{\circ}C^{-1}}$) initially at $300.00 {\rm\ \cdot{}^{\circ}C^{-1}}$ are added. By the conservation of energy,
# \begin{equation*}
# q_{\rm H_2O} + q_{\rm Pb} = m_{\rm H_2O}C_{\rm H_2O}\Delta T_{\rm H_2O} + m_{\rm Pb}C_{\rm Pb}\Delta T_{\rm Pb} = 0,
# \end{equation*}
# where $\Delta T_{\rm A} = T - T_{\rm A}$ is the difference between the common final temperature of the water+lead system $T$ and each component's initial temperature $T_{\rm A}$.
#
# In the cell below,
# 1. Declare real, positive SymPy variables representing the common final temperature $T$ and each individual component's mass, specific heat capacity, and initial temperature.
# 2. Define the conservation of energy equation above and assign it to the Python variable `eqn_to_solve`
# 3. Solve the equation for the common final temperature and evaluate to a floating-point result.
# :::

# %%
# YOUR TURN

# %% [markdown]
# ::::{warning}✅ Check Yourself
# :icon:false
# :class:dropdown
# You should have determined that $T\approx 33.29 {\rm\ {}^{\circ}C}$.
# :::{tip}🐍 Code Key
# :icon:false
# :class:dropdown
# Your code solving this example could resemble
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN
# ## Declare variables & define heat equation
# var('m1 m2 C1 C2 T1 T2 T', real=True, positive=True, nonzero=True)
# eqn_to_solve =@ m1*C1*(T-T1) + m2*C2*(T-T2) = 0
#
# ## Solve for common final temp & evaluate
# solns = solve(eqn_to_solve.subs({m1:50.00, C1:4.184, T1:25.00, m2:50.00, C2:0.130, T2:300.00}), T)
# solns[0].evalf()
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle T = 33.2869728471952$
# :::
# ::::

# %% [markdown]
# ## III.D. Extracting Numerical Values from Solved Equations

# %% [markdown]
# After an equation has been solved (either manually or automatically) for a variable and evaluated to by way of substitution, the result is a SymPy equation which is not directly usable for subsequent calculations. While we have already seen how to convert a decimal number from a derived SymPy object to a native Python `float` using typecasting, how can we extract the number itself from an equation which has been solved?

# %% [markdown]
# :::{tip}🐍 Extracting a Numerical Value from One Side of a Solved Equation
# :icon:false
# If the SymPy equation $P = 22.344382$ was obtained after solving and evaluating the ideal gas law for a given system and has been assigned to the Python variable `soln`, the numerical value itself can be extracted from the right-hand-side of the equation using the `.rhs` attribute:
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration: Extracting a Numerical Value from One Side of an Equation
# # Extract right-hand-side of named SymPy equation, typecast to Python float & store
# P_val = float(soln.rhs)
# ```
# Similarly, the `.lhs` attribute can be used to directly access the left-hand side of a SymPy equation.
# :::

# %% [markdown]
# :::{warning}⚒️ Your Turn
# :icon:false
# Determine the activation energy $E_a$ according to [Eqn. %s](#eqn:arrhenius-k) for a reaction with second-order rate constant $k = 1.4\times 10^{14} {\rm\ M^{-1}\cdot s^{-1}}$ and frequency factor $A = 12.213 {\rm\ M^{-1}s^{-1}}$ at $T=310 K$. Once you determine $E_a$, extract its numerical value as type `float` and assign it to the Python variable `Ea_val`.
# :::

# %%
# YOUR TURN

# %% [markdown]
# :::{warning} ✅ Check Yourself
# :icon:false
# :class:dropdown
# You should have determined that for this reaction at $T = 310 {\rm\ K}$, $E_a \approx 77.5 {\rm\ kJ}$.
#
# :::{tip}🐍 Code Key
# :icon:false
# :class:dropdown
# Your code solving this example could resemble the following:
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN
# ## Declare variables, define Arrhenius
# var('k E T R A', real=True, positive=True, nonzero=True)
# arrhenius =@ k = A*exp(E/(R*T))
#
# ## Substitute & solve for E, float eval, return
# Ea_val = float(solve(arrhenius.subs({k:1.4E14, A:12.213, T:310, R:8.314}), E)[0].evalf().rhs)
#
# ## Printing
# print(f"The activation energy for the reaction at 310 K is E_a = {Ea_val:3.2E} J")
# ```
# ```{code}txt
# :filename:Cell Output
# The activation energy for the reaction at 310 K is E_a = 77.50 kJ
# ```
# ::::::

# %% [markdown]
# # IV. Additional Considerations

# %% [markdown]
# Now that we have a reasonable understanding of how to apply SymPy to solve chemical problems, there are a few additional considerations which must be briefly discussed to avoid specific "gotcha's" that may arise in specific contexts.

# %% [markdown]
# ## IV.A. Greek Letters as SymPy Variables

# %% [markdown]
# In many physical and chemical applications, it is desirable to declare a Greek letter for use as a SymPy variable.

# %% [markdown]
# ::::{tip}🐍 Greek Letters as SymPy Variables
# :icon:false
# To declare a Greek letter as a SymPy variable, simply spell out the letter in your call to the `var()` function:
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration: Greek letters as SymPy variables
# var('alpha beta gamma')
# ```
# After these Greek letters have been declared as SymPy variables, they can be used to define expressions by simply spelling them out:
# ```{code}python
# :linenos:
# :filename:Syntax Demonstration
# var('rho mu nu z')
# eqn =@ z = (rho/mu)*exp(nu)
# eqn
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle z = \frac{\rho}{\mu} e^{\nu}$
# :::
# ::::

# %% [markdown]
# Particularly for quantum mechanics or other applications dealing with light, it may be desirable to declare the Greek letter $\lambda$ as a SymPy variable to represent wavelength. When written out in the Latin alphabet, the character $\lambda$ is spelled "lambda" --- however this is already a _reserved word_ in Python with a specific syntactic meaning in the programming language.
#
# While Python itself will not prevent a reserved word from being overwritten (by, e.g., raising a syntax error), the authors of the SymPy library actually changed the Latin spelling for the Greek letter $\lambda$ to avoid this possibility entirely.

# %% [markdown]
# :::{tip}🐍 Using $\lambda$ & $\Lambda$ as a SymPy Variable
# :icon:false
# To declare a SymPy variable which represents the Greek letters $\lambda$ and $\Lambda$, you must spell it out as `lamda` and `Lamda` (i.e., without the "b" from the proper Latin spelling):
# ```{code}python
# :filename:Syntax Demonstration
# var('lamda Lamda')
# display(lamda, Lamda)
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $\displaystyle \lambda\\$
# $\displaystyle \Lambda$
# ::::::

# %% [markdown]
# ## IV.B. Units in SymPy Expressions

# %% [markdown]
# For scientific applications, bare numbers are meaningless without an accompanying unit. While there is no native functionality in SymPy to accommodate units, the `algebra_with_sympy` wrapper library does define the ability to declare and manipulate units.

# %% [markdown]
# ::::{tip}🐍 Declaring Units with `units()`
# :icon:false
# Before units can be used in SymPy, they must first be declared using the `units()` function in an identical manner to declaring a SymPy variable with the `var()` function.
#
# For example, to declare units of meters, seconds, and kilograms:
# ```{code}python
# :linenos:
# :filename:Syntax for the units() function
# units('m s kg')
# ```
# Once units have been declared, they can be substituted into a previously defined SymPy expression and used algebraically to perform dimensional analysis, however units in some expressions may not completely simplify.
# :::{warning}⚠️ Author Caution: Unit Relationships & Conversions
# :icon:false
# :class:dropdown
# Units defined using the `units()` function are unaware of any relationships between them, either by way of metric prefix, definition, or conversion factor. This represents a major difference between how we might expect declared units to behave and how they _actually_ behave. Defining and using units for dimensional analysis is therefore almost always more trouble than it is worth.[^fn:algwsym-units]
# :::
# :::{danger}⛔️ Author Warning: NEVER Substitute Values with Units into Expressions
# :icon:false
# :class:dropdown
# While it is technically possible to substitute numerical values _with_ associated units defined with the `units()` function into a SymPy expression using the `algebra_with_sympy` wrapper library, ***using this functionality is NOT recommended*** as it will break the SymPy `solve()` function and because of the challenges of incomplete unit simplification warned about above.
# :::
# [^fn:algwsym-units]: This is the opinion of the lesson author, based on three years of experience using the `algebra-with-sympy` wrapper library for both his personal purposes and when teaching these skills in his Physical Chemistry courses. The only significant use case he has found for this functionality is the extremely complicated dimensional analysis that arises in the context of deriving anharmonic rovibrational spectroscopic constants from quantum chemically constructed potential energy surfaces.
# ::::

# %% [markdown]
# ## IV.C. Logarithms in Python & SymPy

# %% [markdown]
# Let's consider that we wish to determine the pH of solution of formic acid with some formal concentration $F$. This corresponds to the macroscopic equilibrium
# \begin{equation*}
# {\rm HA}\;\;\; +\;\;\; {\rm H_2O}\;\;\; \stackrel{K_a}{\leftrightharpoons}\;\;\; {\rm H_3O^+}\;\;\; +\;\;\; {\rm A^-}
# \end{equation*}

# %% [markdown]
# Taking the formal concentrations of hydronium and formate to be 0 M, the ICE table for this system implies that at equilibrium, the reaction quotient expression becomes
# \begin{equation*}
# K_a = \frac{[{\rm H_3O^+}]_{\rm eq}[{\rm A^-}]_{\rm eq}}{[{\rm HA}]_{\rm eq}} = \frac{x^2}{F - x},
# \end{equation*}
# where $F$ is the formal concentration of our formic acid solution and $x$ is the unknown change in formal concentrations necessary for the system to reach equilibrium.

# %% [markdown]
# After using the `solve()` function to solve for the unknown change in concentration $x$ necessary to reach equilibrium, the pH can be determined simply by taking the common logarithm of $x$:
# \begin{equation*}
# {\rm pH} = -\log{[{\rm H_3O^+}]_{\rm eq}} = -\log{x}
# \end{equation*}
# Unfortunately, the mathematical simplicity of computing the pH brings up a particular complication of Python and many other programming languages.

# %% [markdown]
# ::::{danger}☢️ Danger: Logarithms in Python
# :icon:false
# Unlike in a normal mathematical context, where "$\log$" is understood to represent the common logarithm and "$\ln$" is understood to mean the natural logarithm, Python and many other programming languages actually use `log` to mean the natural logarithm and `log10` to mean the common logarithm.
#
# Because this and future lessons involve both the numerical evaluation and symbolic manipulation of the natural & common logarithms, the logarithm functions from two separate libraries have been imported into this notebook in the {u}`[Package Imports](#package-imports)` section, summarized below:
#
# | Characteristic                                                        | Natural Logarithm | Common Logarithm |
# |:----------------------------------------------------------------------|:-----------------:|:----------------:|
# | Base                                                                  | $e$               | $10$             |
# | Mathematical notation                                                 | $\ln{x}$          | $\log{x}$        |
# | Function from the `math` Library (standalone numerical evaluation)    | `mlog()`          | `mlog10()`       |
# | Function from the `sympy` Library (symbolic manipulations & calculus) | `sylog()`         | `sylog10()`      |
#
# :::{tip}🐍 Import Aliases for Logarithmic Functions
# :icon:false
# :class:dropdown
# In both the `math` and `sympy` libraries, the natural and common logarithm functions have identical names. To avoid name clashes, these functions were imported in {u}`[Package Imports](#package-imports)` section, with the aliases tabulated above defined on lines 5-6 and 11-12 (highlighted below):
# ```{code}python
# :linenos:
# :filename:Python Input
# :emphasize-lines: 5,6,11,12
# # EXECUTE: Import some packages that we will use later
# from algebra_with_sympy import * # Automatically imports sympy
# algwsym_config.output.solve_to_list = True # Makes automatic solution outputs a list for usability
# import math
# from math import log as mlog
# from math import log10 as mlog10
# import numpy as np
# import scipy as sp
# from sympy.plotting import plot as symplot
# from IPython.display import display, Markdown
# from sympy.functions.elementary.exponential import log as sylog
# from sympy.codegen.cfunctions import log10 as sylog10
# print(f"This notebook is running Algebra_with_Sympy version {str(algwsym_version)}.")
# ```
# :::
# ::::

# %% [markdown]
# :::{warning} ⚒️ Your Turn
# :icon: false
#
# In the cell below, determine the pH of a 0.250 M solution of formic acid ($K_a = 1.8\times 10^{-4}$).
# :::

# %%
# YOUR TURN: Solve ICE table for formic acid eq'm with `solve()` function

# %% [markdown]
# :::{warning} ✅ Check Yourself
# :icon:false
# :class:dropdown
# You should have determined that for a 0.250 M solution of formic acid, ${\rm pH} \approx 2.18$.
#
# Your code for the task above could resemble the following:
# ```{code} python
# :filename: Python Input
# :linenos:
# # YOUR TURN: Solve ICE table for formic acid eq'm with `solve()` function
# ## Declare SymPy variables over proper domain
# var('x K_a', real=True, nonzero=True, positive=True)
# var('F', real=True, nonnegative=True)
#
# ## Define numerical values for Ka & F without units
# K_a_val = 1.8E-4 # unitless
# F_val = 0.250 # unitless
#
# ## Define equlibrium constant expression, assign to Python variable `eqm`
# eqm =@ K_a = x**2 / (F - x)
#
# ## Substitute, solve for x, extract decimal, typecast to float
# x_val = float(solve(eqm.subs({K_a:K_a_val, F:F_val}), x)[0].rhs)
#
# ## Compute pH
# pH_val = -mlog10(x_val)
#
# ## Printing
# print(f"The pH of a {F_val:3.3f} M solution of formic acid (Ka = {K_a_val:1.1E}) is pH = {pH_val:3.2f}.")
# ```
# ```{code} txt
# :filename: Cell Output
# The pH of a 0.250 M solution of formic acid (Ka = 1.8E-04) is pH = 2.18.
# ```
# :::

# %% [markdown]
# # V. End-of-Lesson Exercises

# %% [markdown]
# :::{exercise} Heat Transfer & Calorimetry $\vert$ {u}`[OpenStax $\S$5.2](https://openstax.org/books/chemistry-2e/pages/5-2-calorimetry)`
# :label:ex:calorimetry
# A 360.0-g piece of rebar (a steel rod used for reinforcing concrete) is dropped into 425 mL of water (density 1.00 g/mL) at 24.0°C. The final temperature of the water was measured as 42.7°C. Calculate the initial temperature of the piece of rebar. Assume the specific heat of steel is approximately the same as that for iron (Table 5.1), and that all heat transfer occurs between the rebar and the water (there is no heat exchange with the surroundings).
# :::

# %% [markdown]
# ~~~{solution}ex:calorimetry
# :class:dropdown
# :open:false
# One possible solution for the problem could be
#
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN: Solve the exercise above here!
# ## Declaring variables
# var('q_r m_r C_r T_r', real=True) # Rebar properties
# var('q_w m_w C_w T_w', real=True) # Water properties
# var('T_f', real=True) # Common final temperature
#
# ## Declaring numerical values for variables
# m_r_val = 360.0 # in grams
# C_r_val = 0.449 # in J / g / degreesC
#
# m_w_val = 425.0 # in grams
# C_w_val = 4.184 # in J / g / degreesC
# T_w_val = 24.0 # in degreesC
#
# T_f_val = 42.7 # in degreesC
#
# ## Define general equations to use
# E_conserv =@ q_r + q_w = 0 # Energy conservation
# rebar_heat =@ q_r = m_r*C_r*(T_f - T_r) # Heat change from perspective of rebar
# water_heat =@ q_w = m_w*C_w*(T_f - T_w) # Heat change from perspective of water
#
# ## Substitute water_heat & rebar_heat expressions into E_conserv to make problem equation
# problem = E_conserv.subs({q_r:rebar_heat.rhs, q_w:water_heat.rhs})
#
# ## Substitute numerical values into problem equation
# problem = problem.subs({m_r: m_r_val,
#                         C_r: C_r_val,
#                         m_w: m_w_val,
#                         C_w: C_w_val,
#                         T_w: T_w_val,
#                         T_f: T_f_val
#                        })
#
# ## Rearrange problem eqn for initial rebar temperature (will be in degreesC)
# solve(problem, T_r)[0].evalf()
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $T_r = 248.418510269735$
# :::
# ~~~

# %% [markdown]
# :::{exercise} Energy & Wavelengths of Bohr-Orbit Transitions $\vert$ {u}`[OpenStax $\S$6.2](https://openstax.org/books/chemistry-2e/pages/6-2-the-bohr-model)`
# :label:ex:bohr-model
# What is the energy (in joules) and the wavelength (in meters) of the line in the spectrum of hydrogen that represents the movement of an electron from Bohr orbit with $n = 4$ to the orbit with $n = 6$? In what part of the electromagnetic spectrum do we find this radiation?
# :::

# %%
# YOUR TURN: Solve the exercise above here!

# %% [markdown]
# ~~~{solution}ex:bohr-model
# :class:dropdown
# :open:false
# One possible solution for the problem could be
#
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN: Solve the exercise above here!
# ## Bohr formula setup
# ### Variables
# var('n_f n_i', integer=True, nonzero=True, postivie=True)
# var('dE R_H', real=True)
#
# ### Constants & variable values
# R_H_val = 2.179E-18
# n_f_val = 6
# n_i_val = 4
#
# ### Equation definition
# bohr =@ dE = -R_H*((1/n_f) - (1/n_i))
#
# ## Planck & light wave formulas setup
# ### Variables
# var('E_photon h c lamda nu')
#
# ### Constants & variable values
# h_val = 6.626E-34
# c_val = 2.9979E8
#
# ### Equation definitions
# lightwave =@ c = lamda*nu
# planck =@ E_photon = h*nu
#
# ## Problem Solution
# ### Excitation energy
# dE_val = float(bohr.subs({R_H: R_H_val, n_f: n_f_val, n_i: n_i_val}).rhs)
# print(f'dE = {dE_val} J')
#
# ### Excitation wavelength
# tosolve = planck.subs({nu: (lightwave/lamda).lhs, E_photon: dE})
# wavelength = solve(tosolve, lamda)[0].subs({dE: dE_val, c: c_val, h: h_val}).evalf()
# lamda_val = float(wavelength.rhs)
# print(f"Excitation wavelength = {lamda_val} m (near IR region)")
# ```
# ```{code}txt
# :filename:Cell Output
# dE = 1.8158333333333336e-19 J
# Excitation wavelength = 1.093937699862322e-06 m (near IR region)
# ```
# ~~~

# %% [markdown]
# :::{exercise} Vapor Pressure of an Ideal Solution $\vert$ {u}`[OpenStax $\S$11.4](https://openstax.org/books/chemistry-2e/pages/11-4-colligative-properties)`
# :label:ex:colligative-prop
# Compute the vapor pressure of an ideal solution containing 92.1 g of glycerin, C$_3$H$_5$(OH)$_3$, and 184.4 g of ethanol, C$_2$H$_5$OH, at 40°C. The vapor pressure of pure ethanol is 0.178 atm at 40°C. Glycerin is essentially nonvolatile at this temperature.
# :::

# %%
# YOUR TURN: Solve the exercise above here!

# %% [markdown]
# ~~~{solution}ex:colligative-prop
# :class:dropdown
# :open:false
# One possible solution for the problem could be
#
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN: Solve the exercise above here!
# ## Define variables for mass, MW, & vapor pressure for each solution component
# gly_mass = 92.1    # g
# gly_MW = 92.094    # g/mol
# Pstar_gly = 0      # atm
# etoh_mass = 184.4  # g
# etoh_MW = 46.069   # g/mol
# Pstar_etoh = 0.178 # atm
#
# ## Convert masses of glycerin & ethanol to moles
# gly_mol = gly_mass * (1/gly_MW)
# etoh_mol = etoh_mass * (1/etoh_MW)
#
# ## Compute mole fractions of ethanol and glycerin
# X_etoh = etoh_mol / (etoh_mol + gly_mol)
# X_gly = gly_mol / (etoh_mol + gly_mol)
#
# ## Compute solution vapor pressure from ethanol vapor pressure from Raoult's Law
# P_soln = Pstar_gly * X_gly + Pstar_etoh * X_etoh
#
# print(f"Vapor pressure of ideal solution at 40C: P = {P_soln:4.3f} atm")
# ```
# ```{code}txt
# :filename:Cell Output
# Vapor pressure of ideal solution at 40C: P = 0.142 atm
# ```
# ~~~

# %% [markdown]
# :::{exercise} Integrated Rate Law of a 2nd Order Reaction $\vert$ {u}`[OpenStax $\S$12.4](https://openstax.org/books/chemistry-2e/pages/12-4-integrated-rate-laws)`
# :label:ex:kinetics
# The reaction of butadiene gas (C$_4$H$_6$) to yield C$_8$H$_{12}$ gas is described by the equation:
# $$2\ {\rm C_4H_6\ (g)} \longrightarrow {\rm C_8H_{12}\ (g)}$$
#
# This “dimerization” reaction is second order with a rate constant equal to $5.76\times 10^{−2}\ {\rm L\ mol^{-1} min^{−1}}$ under certain conditions. If the initial concentration of butadiene is 0.200 M, what is the concentration after 10.0 min?
#
# :::{tip}💡 Hint
# :icon:false
# :class:dropdown
# For the general second order elementary reaction
# $$2 {\rm A}\; \rightleftarrows\; {\rm products}$$
# the 2nd order integrated rate law (taken from {u}`[Table 12.2 in OpenStax $\S$12.4](https://openstax.org/books/chemistry-2e/pages/12-4-integrated-rate-laws#fs-idm117482272))` is given by
# $$\frac{1}{[A]} = kt + \frac{1}{[A]_0}$$
# ::::::

# %%
# YOUR TURN: Solve the exercise above here!

# %% [markdown]
# ~~~{solution}ex:kinetics
# :class:dropdown
# :open:false
# One possible solution for the problem could be
#
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN: Solve the exercise above here!
# ## Variable declaration
# var('A k t A_0', real=True, nonnegative=True)
#
# ## Constants given in problem
# k_val = 5.76E-2 # M/min
# A_0_val = 0.200 # M
# t_val = 10 # min
#
# ## Define named SymPy expression for 2nd order integrated rate law
# integrated_2nd_order =@ (1 / A) = k*t + (1 / A_0)
#
# ## Solve for the concentration of A at later time, and float evaluate
# solve(integrated_2nd_order.subs({k: k_val, A_0: A_0_val, t: t_val}), A)[0].evalf()
# ```
# :::{note}⏎ Cell Output
# :icon:false
# $A = 0.179340028694405$
# :::
# ~~~

# %% [markdown]
# :::{exercise} Equilibrium Concentrations from Initial Concentrations $\vert$ {u}`[OpenStax $\S$13.4](https://openstax.org/books/chemistry-2e/pages/13-4-equilibrium-calculations)`
# :label:ex:eqm
# Acetic acid (CH$_3$CO$_2$H) reacts with ethanol (C$_2$H$_5$OH) to form water and ethyl acetate (CH$_3$CO$_2$C$_2$H$_5$) in a solution where dioxane (C$_4$H$_8$O$_2$; d) is the solvent:
# $${\rm CH_3CO_2H\ (d) + C_2H_5OH\ (d)} \rightleftharpoons {\rm CH_3CO_2C_2H_5\ (d) + H_2O\ (d)}$$
#
# The equilibrium constant for this reaction in dioxane is $K_c = 4.0$. What are the equilibrium concentrations for a mixture that is initially 0.15 M in CH$_3$CO$_2$H, 0.15 M in C$_2$H$_5$OH, 0.40 M in CH$_3$CO$_2$C$_2$H$_5$, and 0.40 M in H$_2$O?
#
# :::{tip}💡 Hints
# :icon:false
# :class:dropdown
# 1. This macroscopic equilibrium is occurring in the solvent dioxane --- as indicated in the reaction by the parenthetical phases "(d)" for all species --- _not aqueous solution._ Because it's not an aqueous system, don't forget to include water in your ICE table and reaction quotient expression!!
# 2. Don't forget to check which direction the reaction will proceed towards equilibrium by comparing the initial value of $Q$ to the equilibrium constant $K_c$.
# 3. Rather than trying to solve the entire problem in a single code cell, break it into separate cells where convenient in the problem solving process.
# ::::::

# %%
# YOUR TURN: Solve the exercise above here!

# %% [markdown]
# ~~~{solution}ex:eqm
# :class:dropdown
# :open:false
# One possible solution for the problem could be
#
# ```{code}python
# :linenos:
# :filename:Python Input
# # YOUR TURN: Solve the exercise above here!
# ## Define Python variables for formal concentrations (F) of each species & eq'm constant (Kc)
# Kc = 4.0
# F_HAc = 0.15  # M
# F_EtOH = 0.15 # M
# F_EtAc = 0.40 # M
# F_H2O = 0.40  # M
#
# ## Define SymPy variables & reaction quotient expression
# ### Reaction quotient Q & eq'm constant K; define scopes to be positive & real
# var('Q', real=True, positive=True)
# var('K', real=True, positive=True)
# ### Change in formal concentration, x; define scope to be real
# var('x', real=True)
# ### Concentrations of each species; define scope to be positive & real
# HAc = Symbol('[HAc]')
# EtOH = Symbol('[EtOH]')
# EtAc = Symbol('[EtAC]')
# H2O = Symbol('[H2O]')
#
# ### Define SymPy expression for reaction quotient, assign to Python variable rxn_quotient
# rxn_quotient =@ Q = (EtAC * H2O) / (HAc * EtOH)
#
# ## Evaluate initial reaction quotient using formal concentrations
# Q_i = rxn_quotient.subs({EtOH: F_EtOH, HAc: F_HAc, EtAC: F_EtAc, H2O: F_H2O}).evalf().rhs
#
# ## Compare initial Q value to K, determine direction of net reaction towards equilibrium
# print("Q < K...net rxn rightwards!") if bool(Q_i < Kc) else print("Q > K...net rxn leftwards!")
#
# ## Set up reaction quotient expression at equilibrium, with net rxn in correct direction
# K_expression = rxn_quotient.subs({Q: Kc,
#                                   HAc: F_HAc + x,
#                                   EtOH: F_EtOH + x,
#                                   EtAc: F_EtAc - x,
#                                   H2O: F_H2O - x
#                                  })
#
# ## Solve K expression for unknown change x
# x1_expr, x2_expr = solve(K_expression, x)
# x1 = float(x1_expr.rhs)
# x2 = float(x2_expr.rhs)
# print(f"Solutions to K expression: x1 = {x1}, x2 = {x2}")
# print(f"Rejecting solution x1 = {x1}, keeping solution x2 = {x2}")
# x_val = x2
#
# ## Compute final equilibrium concentrations
# E_HAc = F_HAc + x_val  # M
# E_EtOH = F_EtOH + x_val # M
# E_EtAc = F_EtAc - x_val # M
# E_H2O = F_H2O - x_val  # M
# print("\nEquilibrium concentrations:")
# print(f"\t[HAc]eq = {E_HAc:4.3f} M")
# print(f"\t[EtOH]eq = {E_EtOH:4.3f} M")
# print(f"\t[EtAc]eq = {E_EtAc:4.3f} M")
# print(f"\t[H2O]eq = {E_H2O:4.3f} M")
#
# ## Check that equilibrium concentrations get close to equilibrium constant when plugged back into Q expr
# sanity = bool(rxn_quotient.subs({Q: Kc,
#                                  HAc: E_HAc,
#                                  EtOH: E_EtOH,
#                                  EtAc: E_EtAc,
#                                  H2O: E_H2O
#                                  })
#              )
# print(f"\nSanity Check: Does plugging eq'm []s back into Q recover K? {sanity}")
# ```
# ```{code}txt
# :filename:Cell Output
# Q > K...net rxn leftwards!
# Solutions to K expression: x1 = -0.7, x2 = 0.03333333333333333
# Rejecting solution x1 = -0.7, keeping solution x2 = 0.03333333333333333
#
# Equilibrium concentrations:
# 	[HAc]eq = 0.183 M
# 	[EtOH]eq = 0.183 M
# 	[EtAc]eq = 0.367 M
# 	[H2O]eq = 0.367 M
#
# Sanity Check: Does plugging eq'm []s back into Q recover K? True
# ```
# ~~~
